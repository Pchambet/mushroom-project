# %% [markdown]
# # Sanity Checks - Mushroom Dataset
#
# Vérifications de base sur le dataset

# %%
import sys
sys.path.append('../src')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from utils import load_processed_data

# %matplotlib inline
sns.set_style('whitegrid')

# %% [markdown]
# ## Chargement des données

# %%
df = load_processed_data()
print(f"Dataset shape: {df.shape}")
df.head()

# %% [markdown]
# ## Vérifications de base

# %%
# Types de données
print("Types de données:")
print(df.dtypes)

# %%
# Valeurs manquantes
print("Valeurs manquantes:")
print(df.isna().sum())

# %%
# Distribution de la classe
print("Distribution de la classe:")
print(df['class'].value_counts())
df['class'].value_counts().plot(kind='bar')
plt.title('Distribution Edible vs Poisonous')
plt.show()

# %%
# Nombre de modalités par variable
print("\nNombre de modalités par variable:")
for col in df.columns:
    print(f"{col}: {df[col].nunique()} modalités")
