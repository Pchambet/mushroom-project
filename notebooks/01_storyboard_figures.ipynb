# %% [markdown]
# # Storyboard - Figures principales
#
# Notebook pour visualiser et composer les figures principales du rapport

# %%
import sys
sys.path.append('../src')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
from PIL import Image

# %matplotlib inline
sns.set_style('whitegrid')

figures_dir = Path('../reports/figures')

# %% [markdown]
# ## 1. Statistiques descriptives

# %%
# Charger et afficher les figures de stats descriptives
fig_path = figures_dir / 'desc_target_bar.png'
if fig_path.exists():
    img = Image.open(fig_path)
    plt.figure(figsize=(10, 6))
    plt.imshow(img)
    plt.axis('off')
    plt.title('Distribution des classes')
    plt.show()
else:
    print(f"Exécuter d'abord: python src/02_describe.py")
    print(f"Fichier attendu: {fig_path}")

# %% [markdown]
# ## 2. Analyse ACM

# %%
# Scree plot
fig_path = figures_dir / 'acm_scree.png'
if fig_path.exists():
    img = Image.open(fig_path)
    plt.figure(figsize=(10, 6))
    plt.imshow(img)
    plt.axis('off')
    plt.title('Scree plot - Inertie expliquée')
    plt.show()
else:
    print(f"Exécuter d'abord: python src/03_mca.py")

# %%
# Plan factoriel individus
fig_path = figures_dir / 'acm_individuals_12_color_target.png'
if fig_path.exists():
    img = Image.open(fig_path)
    plt.figure(figsize=(10, 8))
    plt.imshow(img)
    plt.axis('off')
    plt.title('Plan factoriel - ACM (coloré par classe)')
    plt.show()
else:
    print(f"Exécuter d'abord: python src/03_mca.py")

# %% [markdown]
# ## 3. Clustering

# %%
# Dendrogramme et clusters
fig_path = figures_dir / 'cluster_dendrogram.png'
if fig_path.exists():
    img = Image.open(fig_path)
    plt.figure(figsize=(12, 6))
    plt.imshow(img)
    plt.axis('off')
    plt.title('Dendrogramme - CAH')
    plt.show()
else:
    print(f"Exécuter d'abord: python src/04_cluster.py")

# %% [markdown]
# ## 4. Analyse discriminante

# %%
# Matrice de confusion
fig_path = figures_dir / 'da_confusion.png'
if fig_path.exists():
    img = Image.open(fig_path)
    plt.figure(figsize=(8, 6))
    plt.imshow(img)
    plt.axis('off')
    plt.title('Matrice de confusion')
    plt.show()
else:
    print(f"Exécuter d'abord: python src/05_discriminant.py")
